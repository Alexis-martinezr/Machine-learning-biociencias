# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'Datos_Covid\mexico_covid19.csv')
data.head()
# Out:
#       id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  \
# 0   9269    2020-04-12      00011f          25           25          2      0
# 1  33333    2020-04-12      00014e          14           14          2      0
# 2  35483    2020-04-12      000153           8            8          1      0
# 3   7062    2020-04-12      0001b6           9           15          1      0
# 4  23745    2020-04-12      0001c1           9            9          2      0
#
#    ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  CARDIOVASCULAR  \
# 0                25           Sinaloa      SL  ...        2               2
# 1                14           Jalisco      JC  ...        2               2
# 2                 8         Chihuahua      CH  ...        2               2
# 3                 9  Ciudad de Mexico      DF  ...        2               2
# 4                 9  Ciudad de Mexico      DF  ...        2               2
#
#    OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  MIGRANTE PAIS_NACIONALIDAD  \
# 0         1              2           2          2        99           MÃ©xico
# 1         1              2           1         99        99           MÃ©xico
# 2         2              2           2         99        99           MÃ©xico
# 3         1              2           2         99        99           MÃ©xico
# 4         2              2           2         99        99           MÃ©xico
#
#   PAIS_ORIGEN UCI
# 0          97  97
# 1          97   2
# 2          97   2
# 3          97  97
# 4          97  97
#
# [5 rows x 41 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263007 entries, 0 to 263006
# Data columns (total 41 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   263007 non-null  int64
#  1   FECHA_ARCHIVO        263007 non-null  object
#  2   ID_REGISTRO          263007 non-null  object
#  3   ENTIDAD_UM           263007 non-null  int64
#  4   ENTIDAD_RES          263007 non-null  int64
#  5   RESULTADO            263007 non-null  int64
#  6   DELAY                263007 non-null  int64
#  7   ENTIDAD_REGISTRO     263007 non-null  int64
#  8   ENTIDAD              263007 non-null  object
#  9   ABR_ENT              263007 non-null  object
#  10  FECHA_ACTUALIZACION  263007 non-null  object
#  11  ORIGEN               263007 non-null  int64
#  12  SECTOR               263007 non-null  int64
#  13  SEXO                 263007 non-null  int64
#  14  ENTIDAD_NAC          263007 non-null  int64
#  15  MUNICIPIO_RES        263001 non-null  float64
#  16  TIPO_PACIENTE        263007 non-null  int64
#  17  FECHA_INGRESO        263007 non-null  object
#  18  FECHA_SINTOMAS       263007 non-null  object
#  19  FECHA_DEF            263007 non-null  object
#  20  INTUBADO             263007 non-null  int64
#  21  NEUMONIA             263007 non-null  int64
#  22  EDAD                 263007 non-null  int64
#  23  NACIONALIDAD         263007 non-null  int64
#  24  EMBARAZO             263007 non-null  int64
#  25  HABLA_LENGUA_INDIG   263007 non-null  int64
#  26  DIABETES             263007 non-null  int64
#  27  EPOC                 263007 non-null  int64
#  28  ASMA                 263007 non-null  int64
#  29  INMUSUPR             263007 non-null  int64
#  30  HIPERTENSION         263007 non-null  int64
#  31  OTRA_COM             263007 non-null  int64
#  32  CARDIOVASCULAR       263007 non-null  int64
#  33  OBESIDAD             263007 non-null  int64
#  34  RENAL_CRONICA        263007 non-null  int64
#  35  TABAQUISMO           263007 non-null  int64
#  36  OTRO_CASO            263007 non-null  int64
#  37  MIGRANTE             263007 non-null  int64
#  38  PAIS_NACIONALIDAD    263007 non-null  object
#  39  PAIS_ORIGEN          263007 non-null  object
#  40  UCI                  263007 non-null  int64
# dtypes: float64(1), int64(30), object(10)
# memory usage: 82.3+ MB
# None

# %%
data.columns
# Out:
# Index(['id', 'FECHA_ARCHIVO', 'ID_REGISTRO', 'ENTIDAD_UM', 'ENTIDAD_RES',
#        'RESULTADO', 'DELAY', 'ENTIDAD_REGISTRO', 'ENTIDAD', 'ABR_ENT',
#        'FECHA_ACTUALIZACION', 'ORIGEN', 'SECTOR', 'SEXO', 'ENTIDAD_NAC',
#        'MUNICIPIO_RES', 'TIPO_PACIENTE', 'FECHA_INGRESO', 'FECHA_SINTOMAS',
#        'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD', 'NACIONALIDAD', 'EMBARAZO',
#        'HABLA_LENGUA_INDIG', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
#        'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'OTRO_CASO', 'MIGRANTE',
#        'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
data.nunique()
# Out:
# id                     263007
# FECHA_ARCHIVO              53
# ID_REGISTRO            263007
# ENTIDAD_UM                 32
# ENTIDAD_RES                32
# RESULTADO                   2
# DELAY                       1
# ENTIDAD_REGISTRO           32
# ENTIDAD                    32
# ABR_ENT                    32
# FECHA_ACTUALIZACION        46
# ORIGEN                      2
# SECTOR                     14
# SEXO                        2
# ENTIDAD_NAC                33
# MUNICIPIO_RES             359
# TIPO_PACIENTE               2
# FECHA_INGRESO             155
# FECHA_SINTOMAS            154
# FECHA_DEF                  88
# INTUBADO                    4
# NEUMONIA                    3
# EDAD                      117
# NACIONALIDAD                2
# EMBARAZO                    4
# HABLA_LENGUA_INDIG          3
# DIABETES                    3
# EPOC                        3
# ASMA                        3
# INMUSUPR                    3
# HIPERTENSION                3
# OTRA_COM                    3
# CARDIOVASCULAR              3
# OBESIDAD                    3
# RENAL_CRONICA               3
# TABAQUISMO                  3
# OTRO_CASO                   3
# MIGRANTE                    3
# PAIS_NACIONALIDAD          84
# PAIS_ORIGEN                51
# UCI                         4
# dtype: int64

# %%
data['FECHA_DEF'].unique()
# Out:
# array(['9999-99-99', '2020-04-04', '2020-03-28', '2020-03-31',
#        '2020-04-05', '2020-03-25', '2020-03-29', '2020-03-27',
#        '2020-04-03', '2020-04-02', '2020-04-06', '2020-04-08',
#        '2020-04-09', '2020-04-07', '2020-03-22', '2020-04-01',
#        '2020-03-30', '2020-04-11', '2020-04-10', '2020-03-26',
#        '2020-01-13', '2020-03-23', '2020-03-18', '2020-03-24',
#        '2020-04-12', '2020-03-20', '2020-03-09', '2020-03-17',
#        '2020-04-13', '2020-01-11', '2020-02-10', '2020-04-14',
#        '2020-04-15', '2020-01-29', '2020-04-16', '2020-04-17',
#        '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-22',
#        '2020-04-21', '2020-01-15', '2020-04-23', '2020-04-24',
#        '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28',
#        '2020-04-29', '2020-02-28', '2020-04-30', '2020-05-01',
#        '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05',
#        '2020-05-06', '2020-05-07', '2020-05-08', '2020-05-09',
#        '2020-05-10', '2020-05-11', '2020-05-12', '2020-05-13',
#        '2020-05-14', '2020-05-15', '2020-05-16', '2020-05-17',
#        '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21',
#        '2020-02-20', '2020-05-22', '2020-05-23', '2020-05-24',
#        '2020-05-25', '2020-02-23', '2020-05-26', '2020-05-27',
#        '2020-03-21', '2020-05-28', '2020-05-29', '2020-05-30',
#        '2020-05-31', '2020-06-01', '2020-06-02', '2020-06-03'],
#       dtype=object)

# %%
data[data['FECHA_DEF'] != '9999-99-99']['FECHA_DEF'].count()
# Out:
# np.int64(4542)

# %%
data[data['FECHA_DEF'] == '9999-99-99']['FECHA_DEF'].count()
# Out:
# np.int64(258465)

# %%
# Obtención del numero de defunciones
defunciones = []
for i in data['FECHA_DEF']:
    if i == '9999-99-99':
        defunciones.append(2)
    else:
        defunciones.append(1)

# %%
data['defunciones'] = defunciones
data['defunciones'].count()
# Out:
# np.int64(263007)

# %%
data.groupby('defunciones')['defunciones'].count()
# Out:
# defunciones
# 1      4542
# 2    258465
# Name: defunciones, dtype: int64

# %%
def graf_barras(df, x, y, t):
    # Agrupamos y contamos pacientes
    df_g = df.groupby(x)[y].nunique().reset_index()

    # Graficamos
    sns.barplot(data=df_g, x=x, y=y, hue =x)
    plt.title(f'Distribución {t} de {x}')
    plt.xticks(rotation=45)

# %%
def graf_barras_2(df, x, y, n1, n2, titulo):
    df_g = df.groupby(x)[y].nunique().reset_index()
    barras = sns.barplot(data=df_g, x=x, y=y, hue=x, ax=axs[n1,n2])
    
    # Ajustar títulos y etiquetas
    axs[n1,n2].set_title(f'Distribución {titulo} de {x}')
    axs[n1,n2].set_xticklabels(axs[n1,n2].get_xticklabels(), rotation=45, ha='right')

# %%
data_def = data[data['FECHA_DEF'] != '9999-99-99']

nacionalidad = []
for i in data['PAIS_NACIONALIDAD']:
    if i == 'Mexico':
        defunciones.append(2)
    else:
        defunciones.append(1)

# %%
figure, axs = plt.subplots( 2,2, sharey=False, sharex=False, figsize=(15, 7))
graf_barras_2(data, 'ENTIDAD', 'id', 0,0,'enfermos por')
graf_barras_2(data_def, 'ENTIDAD', 'id', 0,1, 'defunciones por',)
graf_barras_2(data, 'NACIONALIDAD', 'id', 1,0,'enfermos por')
graf_barras_2(data_def, 'NACIONALIDAD', 'id',1,1, 'defunciones por')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\3745221093.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[n1,n2].set_xticklabels(axs[n1,n2].get_xticklabels(), rotation=45, ha='right')
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\3745221093.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[n1,n2].set_xticklabels(axs[n1,n2].get_xticklabels(), rotation=45, ha='right')
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\3745221093.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[n1,n2].set_xticklabels(axs[n1,n2].get_xticklabels(), rotation=45, ha='right')
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\3745221093.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[n1,n2].set_xticklabels(axs[n1,n2].get_xticklabels(), rotation=45, ha='right')

# %%
graf_barras_2(data, 'PAIS_NACIONALIDAD', 'id', 1, 0, 'enfermos por')
graf_barras_2(data, 'PAIS_ORIGEN ', 'id', 1, 1, 'enfermos por')
